# %% [markdown]
# ![Ironhack logo](https://i.imgur.com/1QgrNNw.png)
#
# # Lab | StackAPI
# Let's check if you can handle working with an API.
#
# Use [StackAPI](https://stackapi.readthedocs.io/en/latest/), a Python wrapper for the Stack Exchange API, and answer the following questions:
#
# * Question 1: Find the questions and answers of last month.
# * Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.
# * Question 3: Find the answers with id 6784 and 6473.

# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
# your code here
import pandas as pd
import requests
from stackapi import StackAPI

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
# your code here
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', fromdate=1588291200, todate=1590883200)
answers = SITE.fetch('answers', fromdate=1588291200, todate=1590883200)
# the time used in this API is in Unix epoch time!
# https://en.wikipedia.org/wiki/Unix_time
questions
answers
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 712,
#     'user_id': 4667256,
#     'user_type': 'registered',
#     'accept_rate': 76,
#     'profile_image': 'https://graph.facebook.com/860591147318225/picture?type=large',
#     'display_name': 'Gilbert Nwaiwu',
#     'link': 'https://stackoverflow.com/users/4667256/gilbert-nwaiwu'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592856046,
#    'last_edit_date': 1592856046,
#    'creation_date': 1590586160,
#    'answer_id': 62044316,
#    'question_id': 53577835,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 648,
#     'user_id': 3847255,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/1a5ae0e1317d8f367da0af2a68990222?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'pooya13',
#     'link': 'https://stackoverflow.com/users/3847255/pooya13'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592855593,
#    'last_edit_date': 1592855593,
#    'creation_date': 1590644624,
#    'answer_id': 62057783,
#    'question_id': 67273,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 13644699,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/e6e91836fac0b35fd7dd8ae311875852?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Manu Philip',
#     'link': 'https://stackoverflow.com/users/13644699/manu-philip'},
#    'is_accepted': False,
#    'score': -2,
#    'last_activity_date': 1592854897,
#    'last_edit_date': 1592854897,
#    'creation_date': 1590790185,
#    'answer_id': 62095310,
#    'question_id': 52159009,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 21,
#     'user_id': 13468877,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-c3IvpJy07_I/AAAAAAAAAAI/AAAAAAAAAAA/AAKWJJNXqXwMpiBRwIwAS5tkZlHq33jxOA/photo.jpg?sz=128',
#     'display_name': 'Rodolfo Merlo Ali',
#     'link': 'https://stackoverflow.com/users/13468877/rodolfo-merlo-ali'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592852863,
#    'last_edit_date': 1592852863,
#    'creation_date': 1589770561,
#    'answer_id': 61861719,
#    'question_id': 60332960,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 23,
#     'user_id': 1829337,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/90bad96529b9cf7070a3aad8f404b9ff?s=128&d=identicon&r=PG',
#     'display_name': 'Hayden O&#39;Sullivan',
#     'link': 'https://stackoverflow.com/users/1829337/hayden-osullivan'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592851820,
#    'last_edit_date': 1592851820,
#    'creation_date': 1588769026,
#    'answer_id': 61635560,
#    'question_id': 1354999,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 565,
#     'user_id': 1704448,
#     'user_type': 'registered',
#     'accept_rate': 93,
#     'profile_image': 'https://i.stack.imgur.com/ygQUG.png?s=128&g=1',
#     'display_name': 'DPSSpatial',
#     'link': 'https://stackoverflow.com/users/1704448/dpsspatial'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592848978,
#    'last_edit_date': 1592848978,
#    'creation_date': 1588870928,
#    'answer_id': 61663545,
#    'question_id': 28699903,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 5993,
#     'user_id': 11987538,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/rSHXs.png?s=128&g=1',
#     'display_name': '7uc1f3r',
#     'link': 'https://stackoverflow.com/users/11987538/7uc1f3r'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592848289,
#    'last_edit_date': 1592848289,
#    'creation_date': 1588780672,
#    'answer_id': 61639656,
#    'question_id': 61637501,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 5145,
#     'user_id': 7148391,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/KIlov.png?s=128&g=1',
#     'display_name': 'Zohir Salak',
#     'link': 'https://stackoverflow.com/users/7148391/zohir-salak'},
#    'is_accepted': True,
#    'score': 0,
#    'last_activity_date': 1592847887,
#    'last_edit_date': 1592847887,
#    'creation_date': 1589809351,
#    'answer_id': 61870964,
#    'question_id': 61869598,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 196,
#     'user_id': 3310801,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/9acb36508ea02ff74e142ad6d0b5acf3?s=128&d=identicon&r=PG',
#     'display_name': 'Flavio',
#     'link': 'https://stackoverflow.com/users/3310801/flavio'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592844278,
#    'last_edit_date': 1592844278,
#    'creation_date': 1590389840,
#    'answer_id': 61997263,
#    'question_id': 21272146,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 11,
#     'user_id': 11847130,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-YtZ5YCuEI_E/AAAAAAAAAAI/AAAAAAAAABA/T9D2h8bKnPo/photo.jpg?sz=128',
#     'display_name': 'Abdifatah Mohamed',
#     'link': 'https://stackoverflow.com/users/11847130/abdifatah-mohamed'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592841289,
#    'last_edit_date': 1592841289,
#    'creation_date': 1590841111,
#    'answer_id': 62102329,
#    'question_id': 41774046,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1230,
#     'user_id': 9684317,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/15494fc1f2122ece41d73690b3208d05?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Gagan Deep',
#     'link': 'https://stackoverflow.com/users/9684317/gagan-deep'},
#    'is_accepted': False,
#    'score': 11,
#    'last_activity_date': 1592840897,
#    'last_edit_date': 1592840897,
#    'creation_date': 1590815326,
#    'answer_id': 62098091,
#    'question_id': 61992025,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 137,
#     'user_id': 11154841,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/a3cGr.png?s=128&g=1',
#     'display_name': 'Lorenz',
#     'link': 'https://stackoverflow.com/users/11154841/lorenz'},
#    'is_accepted': True,
#    'score': 1,
#    'last_activity_date': 1592840022,
#    'last_edit_date': 1592840022,
#    'creation_date': 1590162531,
#    'answer_id': 61958873,
#    'question_id': 59250636,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1580,
#     'user_id': 1018154,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/o1V9q.png?s=128&g=1',
#     'display_name': 'CodeToLife',
#     'link': 'https://stackoverflow.com/users/1018154/codetolife'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592836029,
#    'last_edit_date': 1592836029,
#    'creation_date': 1589061741,
#    'answer_id': 61704356,
#    'question_id': 19325312,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 10365,
#     'user_id': 5343387,
#     'user_type': 'registered',
#     'accept_rate': 86,
#     'profile_image': 'https://www.gravatar.com/avatar/15a14cec3014822297a08ed6dfae2563?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Matt Schuchard',
#     'link': 'https://stackoverflow.com/users/5343387/matt-schuchard'},
#    'is_accepted': True,
#    'score': 4,
#    'last_activity_date': 1592834586,
#    'last_edit_date': 1592834586,
#    'creation_date': 1590597591,
#    'answer_id': 62048270,
#    'question_id': 62047860,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 4959,
#     'user_id': 1670825,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/d66cde62842b5af0fcd39372343348f3?s=128&d=identicon&r=PG',
#     'display_name': 'Harjot Singh',
#     'link': 'https://stackoverflow.com/users/1670825/harjot-singh'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592831582,
#    'last_edit_date': 1592831582,
#    'creation_date': 1590495736,
#    'answer_id': 62022074,
#    'question_id': 27011131,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 31,
#     'user_id': 7179840,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/78ae0863139d2b7be3f53e498ffdef1b?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Mikezar',
#     'link': 'https://stackoverflow.com/users/7179840/mikezar'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1592831215,
#    'last_edit_date': 1592831215,
#    'creation_date': 1590770914,
#    'answer_id': 62090862,
#    'question_id': 62016243,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 6104494,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/OAc7F.jpg?s=128&g=1',
#     'display_name': 'darencorp',
#     'link': 'https://stackoverflow.com/users/6104494/darencorp'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592826295,
#    'last_edit_date': 1592826295,
#    'creation_date': 1590619227,
#    'answer_id': 62054038,
#    'question_id': 32688688,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1550,
#     'user_id': 13470894,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/2b21cd0def9c9a0d9c1bd42fb27b9136?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'alphaz18',
#     'link': 'https://stackoverflow.com/users/13470894/alphaz18'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592825595,
#    'last_edit_date': 1592825595,
#    'creation_date': 1590521233,
#    'answer_id': 62029876,
#    'question_id': 62025557,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1550,
#     'user_id': 13470894,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/2b21cd0def9c9a0d9c1bd42fb27b9136?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'alphaz18',
#     'link': 'https://stackoverflow.com/users/13470894/alphaz18'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592825573,
#    'last_edit_date': 1592825573,
#    'creation_date': 1589380062,
#    'answer_id': 61777233,
#    'question_id': 61771959,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 918,
#     'user_id': 7763149,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-gJNCXRnZzc0/AAAAAAAAAAI/AAAAAAAAD8Y/cndo9JZ8ZPk/photo.jpg?sz=128',
#     'display_name': 'bajran',
#     'link': 'https://stackoverflow.com/users/7763149/bajran'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592824743,
#    'last_edit_date': 1592824743,
#    'creation_date': 1588571586,
#    'answer_id': 61585926,
#    'question_id': 27539262,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 726,
#     'user_id': 9935654,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-XdoefqMBYAQ/AAAAAAAAAAI/AAAAAAAAIfg/qFXt_RO4q5s/photo.jpg?sz=128',
#     'display_name': 'Carson',
#     'link': 'https://stackoverflow.com/users/9935654/carson'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592823981,
#    'last_edit_date': 1592823981,
#    'creation_date': 1590401551,
#    'answer_id': 62000248,
#    'question_id': 6518788,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 18079,
#     'user_id': 3088138,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/114f33fdece969de35d41038fb0eeb46?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Lutz Lehmann',
#     'link': 'https://stackoverflow.com/users/3088138/lutz-lehmann'},
#    'is_accepted': True,
#    'score': 4,
#    'last_activity_date': 1592820852,
#    'last_edit_date': 1592820852,
#    'creation_date': 1590310006,
#    'answer_id': 61983588,
#    'question_id': 61978904,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 682,
#     'user_id': 10390808,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/FAzdI.jpg?s=128&g=1',
#     'display_name': 'Abhinav Chauhan',
#     'link': 'https://stackoverflow.com/users/10390808/abhinav-chauhan'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592820106,
#    'last_edit_date': 1592820106,
#    'creation_date': 1588940961,
#    'answer_id': 61679178,
#    'question_id': 23978828,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 483,
#     'user_id': 11926970,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/ml3nW.png?s=128&g=1',
#     'display_name': 'Not A Bot',
#     'link': 'https://stackoverflow.com/users/11926970/not-a-bot'},
#    'is_accepted': True,
#    'score': 0,
#    'last_activity_date': 1592819983,
#    'last_edit_date': 1592819983,
#    'creation_date': 1589290943,
#    'answer_id': 61753291,
#    'question_id': 61672972,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 106,
#     'user_id': 844619,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/0a310917880fd4ffa4fcc18cd8079a01?s=128&d=identicon&r=PG',
#     'display_name': 'Dušan Knežević',
#     'link': 'https://stackoverflow.com/users/844619/du%c5%a1an-kne%c5%beevi%c4%87'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592819554,
#    'last_edit_date': 1592819554,
#    'creation_date': 1589818748,
#    'answer_id': 61874165,
#    'question_id': 61817778,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 7049,
#     'user_id': 2641825,
#     'user_type': 'registered',
#     'accept_rate': 59,
#     'profile_image': 'https://www.gravatar.com/avatar/f8f682f30f7a3b07bd67be391e169232?s=128&d=identicon&r=PG',
#     'display_name': 'Paul Rougieux',
#     'link': 'https://stackoverflow.com/users/2641825/paul-rougieux'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592818654,
#    'last_edit_date': 1592818654,
#    'creation_date': 1588560593,
#    'answer_id': 61584424,
#    'question_id': 4028267,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 3295,
#     'user_id': 1491439,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/b16bc04f248a9e11646c5062bea24537?s=128&d=identicon&r=PG',
#     'display_name': 'rob2universe',
#     'link': 'https://stackoverflow.com/users/1491439/rob2universe'},
#    'is_accepted': True,
#    'score': 2,
#    'last_activity_date': 1592818350,
#    'last_edit_date': 1592818350,
#    'creation_date': 1590383455,
#    'answer_id': 61996171,
#    'question_id': 61866268,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1076,
#     'user_id': 11427002,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/ab03cd07eb585cc846cf50609ff7d451?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'R&#233;mi Coulaud',
#     'link': 'https://stackoverflow.com/users/11427002/r%c3%a9mi-coulaud'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592816381,
#    'last_edit_date': 1592816381,
#    'creation_date': 1589638576,
#    'answer_id': 61838199,
#    'question_id': 61834830,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 91,
#     'user_id': 5020138,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/YQUxO.jpg?s=128&g=1',
#     'display_name': 'solmans',
#     'link': 'https://stackoverflow.com/users/5020138/solmans'},
#    'is_accepted': False,
#    'score': 6,
#    'last_activity_date': 1592813758,
#    'last_edit_date': 1592813758,
#    'creation_date': 1589100554,
#    'answer_id': 61709343,
#    'question_id': 51482940,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 298,
#     'user_id': 1506394,
#     'user_type': 'registered',
#     'accept_rate': 7,
#     'profile_image': 'https://i.stack.imgur.com/UOJAZ.png?s=128&g=1',
#     'display_name': 'chriscrossweb',
#     'link': 'https://stackoverflow.com/users/1506394/chriscrossweb'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592813314,
#    'last_edit_date': 1592813314,
#    'creation_date': 1590759848,
#    'answer_id': 62087403,
#    'question_id': 54030722,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 2953,
#     'user_id': 10122791,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/ZaYaT.jpg?s=128&g=1',
#     'display_name': 'Augustin R',
#     'link': 'https://stackoverflow.com/users/10122791/augustin-r'},
#    'is_accepted': False,
#    'score': 3,
#    'last_activity_date': 1592812255,
#    'last_edit_date': 1592812255,
#    'creation_date': 1590421820,
#    'answer_id': 62006070,
#    'question_id': 62006069,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 436,
#     'user_id': 13195468,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/RurAK.jpg?s=128&g=1',
#     'display_name': 'mallocation',
#     'link': 'https://stackoverflow.com/users/13195468/mallocation'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1592811309,
#    'last_edit_date': 1592811309,
#    'creation_date': 1589079858,
#    'answer_id': 61706648,
#    'question_id': 61706533,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 62561,
#     'user_id': 64949,
#     'user_type': 'registered',
#     'accept_rate': 97,
#     'profile_image': 'https://www.gravatar.com/avatar/d36a92237c75c5337c17b60d90686bf9?s=128&d=identicon&r=PG',
#     'display_name': 'Sindre Sorhus',
#     'link': 'https://stackoverflow.com/users/64949/sindre-sorhus'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1592810240,
#    'last_edit_date': 1592810240,
#    'creation_date': 1590826261,
#    'answer_id': 62099616,
#    'question_id': 61386877,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 342,
#     'user_id': 7144427,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/61a27f8c0083642fe66424bff4c29bc3?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'wizzfizz94',
#     'link': 'https://stackoverflow.com/users/7144427/wizzfizz94'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592806844,
#    'last_edit_date': 1592806844,
#    'creation_date': 1589270451,
#    'answer_id': 61746587,
#    'question_id': 12242772,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 22098,
#     'user_id': 202229,
#     'user_type': 'registered',
#     'accept_rate': 74,
#     'profile_image': 'https://www.gravatar.com/avatar/6cc1d82c11563b440c57280ad587ee47?s=128&d=identicon&r=PG',
#     'display_name': 'smci',
#     'link': 'https://stackoverflow.com/users/202229/smci'},
#    'is_accepted': True,
#    'score': 0,
#    'last_activity_date': 1592804733,
#    'last_edit_date': 1592804733,
#    'creation_date': 1590373799,
#    'answer_id': 61994884,
#    'question_id': 61994795,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 13,
#     'user_id': 12875823,
#     'user_type': 'registered',
#     'profile_image': 'https://lh6.googleusercontent.com/-mXfb2egGlD0/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3rdb0vTBbOzBYJt-oeY5zxi9EAdSHA/photo.jpg?sz=128',
#     'display_name': 'acw',
#     'link': 'https://stackoverflow.com/users/12875823/acw'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592792501,
#    'last_edit_date': 1592792501,
#    'creation_date': 1590855161,
#    'answer_id': 62105229,
#    'question_id': 62087265,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 47,
#     'user_id': 13573030,
#     'user_type': 'registered',
#     'profile_image': 'https://lh6.googleusercontent.com/-DknWHv5wCIs/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucmhvqJ_d2evoSMr-jy1aA5EHa_dcg/photo.jpg?sz=128',
#     'display_name': 'onur',
#     'link': 'https://stackoverflow.com/users/13573030/onur'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592791146,
#    'last_edit_date': 1592791146,
#    'creation_date': 1589884551,
#    'answer_id': 61888948,
#    'question_id': 61881284,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 12979,
#     'user_id': 1270003,
#     'user_type': 'registered',
#     'accept_rate': 87,
#     'profile_image': 'https://www.gravatar.com/avatar/67721c78a91de0c2ae41a7ce73bd8c56?s=128&d=identicon&r=PG',
#     'display_name': 'texasbruce',
#     'link': 'https://stackoverflow.com/users/1270003/texasbruce'},
#    'is_accepted': True,
#    'score': 1,
#    'last_activity_date': 1592790355,
#    'last_edit_date': 1592790355,
#    'creation_date': 1588449827,
#    'answer_id': 61565558,
#    'question_id': 61565393,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 3,
#     'user_id': 8524059,
#     'user_type': 'registered',
#     'profile_image': 'https://lh6.googleusercontent.com/-pjXr5SLtC8E/AAAAAAAAAAI/AAAAAAAAACE/tc0e3baiVuw/photo.jpg?sz=128',
#     'display_name': 'Rohit Martires',
#     'link': 'https://stackoverflow.com/users/8524059/rohit-martires'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592788121,
#    'last_edit_date': 1592788121,
#    'creation_date': 1589347220,
#    'answer_id': 61766988,
#    'question_id': 15649244,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 445,
#     'user_id': 2762187,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/qFpaV.png?s=128&g=1',
#     'display_name': 'vahid tajari',
#     'link': 'https://stackoverflow.com/users/2762187/vahid-tajari'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592784288,
#    'last_edit_date': 1592784288,
#    'creation_date': 1589884358,
#    'answer_id': 61888889,
#    'question_id': 61887937,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 17223,
#     'user_id': 6275103,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/X3gDE.jpg?s=128&g=1',
#     'display_name': 'MrGeek',
#     'link': 'https://stackoverflow.com/users/6275103/mrgeek'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592778988,
#    'last_edit_date': 1592778988,
#    'creation_date': 1589741016,
#    'answer_id': 61856941,
#    'question_id': 61856798,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 37,
#     'user_id': 13149396,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-WlzjE-AKUKI/AAAAAAAAAAI/AAAAAAAAAAA/AAKWJJNYCIASZBRm74SAdgwoqid6pfGY2g/photo.jpg?sz=128',
#     'display_name': 'Alessandro Carella',
#     'link': 'https://stackoverflow.com/users/13149396/alessandro-carella'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592773503,
#    'last_edit_date': 1592773503,
#    'creation_date': 1590242237,
#    'answer_id': 61973119,
#    'question_id': 61919349,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 5,
#     'user_id': 11773923,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/EXRnG.jpg?s=128&g=1',
#     'display_name': 'ijka5844',
#     'link': 'https://stackoverflow.com/users/11773923/ijka5844'},
#    'is_accepted': False,
#    'score': -1,
#    'last_activity_date': 1592771795,
#    'last_edit_date': 1592771795,
#    'creation_date': 1589580613,
#    'answer_id': 61829142,
#    'question_id': 33527616,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1212,
#     'user_id': 2789024,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/14b698231f273dffa4c39b8eff183544?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'darmis',
#     'link': 'https://stackoverflow.com/users/2789024/darmis'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592770112,
#    'last_edit_date': 1592770112,
#    'creation_date': 1588932908,
#    'answer_id': 61676822,
#    'question_id': 17711146,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 50311,
#     'user_id': 1851712,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/37d341e1389813471ddcec85970752a6?s=128&d=identicon&r=PG',
#     'display_name': 'Henrik',
#     'link': 'https://stackoverflow.com/users/1851712/henrik'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592769175,
#    'last_edit_date': 1592769175,
#    'creation_date': 1590231595,
#    'answer_id': 61971002,
#    'question_id': 61961836,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 201,
#     'user_id': 4389437,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-wN1vD1B8O3I/AAAAAAAAAAI/AAAAAAAAABM/BPZGU4dvnHw/photo.jpg?sz=128',
#     'display_name': 'ThunderBird',
#     'link': 'https://stackoverflow.com/users/4389437/thunderbird'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1592761844,
#    'last_edit_date': 1592761844,
#    'creation_date': 1588796711,
#    'answer_id': 61644708,
#    'question_id': 51069552,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 901,
#     'user_id': 1840877,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://i.stack.imgur.com/Q3kOv.jpg?s=128&g=1',
#     'display_name': 'kundan',
#     'link': 'https://stackoverflow.com/users/1840877/kundan'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592754595,
#    'last_edit_date': 1592754595,
#    'creation_date': 1589361525,
#    'answer_id': 61770755,
#    'question_id': 60643134,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 6322,
#     'user_id': 13552470,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/Hh2jv.png?s=128&g=1',
#     'display_name': 'Ann Zen',
#     'link': 'https://stackoverflow.com/users/13552470/ann-zen'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592749511,
#    'last_edit_date': 1592749511,
#    'creation_date': 1589757425,
#    'answer_id': 61860048,
#    'question_id': 61683331,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 9234426,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-8nm4ysWUarU/AAAAAAAAAAI/AAAAAAAACtc/1LiKlF6N61E/photo.jpg?sz=128',
#     'display_name': 'Roman Hricišin',
#     'link': 'https://stackoverflow.com/users/9234426/roman-hrici%c5%a1in'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592749145,
#    'last_edit_date': 1592749145,
#    'creation_date': 1588566920,
#    'answer_id': 61585257,
#    'question_id': 61580835,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 4084,
#     'user_id': 1301237,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://www.gravatar.com/avatar/79d272ebb9a54970a659322c7f4b23cd?s=128&d=identicon&r=PG',
#     'display_name': 'Ifnot',
#     'link': 'https://stackoverflow.com/users/1301237/ifnot'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592748961,
#    'last_edit_date': 1592748961,
#    'creation_date': 1590509181,
#    'answer_id': 62026489,
#    'question_id': 29310530,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 2692,
#     'user_id': 704879,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/96e81f8ab5b17751354cea22578981f2?s=128&d=identicon&r=PG',
#     'display_name': 'woohoo',
#     'link': 'https://stackoverflow.com/users/704879/woohoo'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592745473,
#    'last_edit_date': 1592745473,
#    'creation_date': 1590688218,
#    'answer_id': 62071264,
#    'question_id': 29534112,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 7334,
#     'user_id': 3779853,
#     'user_type': 'registered',
#     'accept_rate': 85,
#     'profile_image': 'https://www.gravatar.com/avatar/1cbdb458aafbdc1095f165a616444917?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'phil294',
#     'link': 'https://stackoverflow.com/users/3779853/phil294'},
#    'is_accepted': False,
#    'score': -3,
#    'last_activity_date': 1592744809,
#    'last_edit_date': 1592744809,
#    'creation_date': 1588519628,
#    'answer_id': 61576970,
#    'question_id': 57722131,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 39,
#     'user_id': 10143018,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-YV7bColRMX0/AAAAAAAAAAI/AAAAAAAAALc/DOT43nCSGVg/photo.jpg?sz=128',
#     'display_name': 'Suz&#39;l Shrestha',
#     'link': 'https://stackoverflow.com/users/10143018/suzl-shrestha'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592736284,
#    'last_edit_date': 1592736284,
#    'creation_date': 1589970062,
#    'answer_id': 61910663,
#    'question_id': 38136854,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 188,
#     'user_id': 11151112,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-PVEIQyItnC4/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3rd1bqt6zM8Rcg1ATF0ZOt-ZDxLLrw/mo/photo.jpg?sz=128',
#     'display_name': 'applemonkey496',
#     'link': 'https://stackoverflow.com/users/11151112/applemonkey496'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1592736158,
#    'last_edit_date': 1592736158,
#    'creation_date': 1589217084,
#    'answer_id': 61735314,
#    'question_id': 10311092,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 959,
#     'user_id': 9504749,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-5v7VMxmmv1Q/AAAAAAAAAAI/AAAAAAAAAWE/402P87Q3Mm8/photo.jpg?sz=128',
#     'display_name': 'dumbPy',
#     'link': 'https://stackoverflow.com/users/9504749/dumbpy'},
#    'is_accepted': True,
#    'score': 4,
#    'last_activity_date': 1592730390,
#    'last_edit_date': 1592730390,
#    'creation_date': 1589579120,
#    'answer_id': 61828841,
#    'question_id': 61827063,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 981,
#     'user_id': 7015661,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://i.stack.imgur.com/Gl8tt.png?s=128&g=1',
#     'display_name': 'TM00',
#     'link': 'https://stackoverflow.com/users/7015661/tm00'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592730389,
#    'last_edit_date': 1592730389,
#    'creation_date': 1589829259,
#    'answer_id': 61877280,
#    'question_id': 50828437,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1621,
#     'user_id': 1525751,
#     'user_type': 'registered',
#     'accept_rate': 50,
#     'profile_image': 'https://www.gravatar.com/avatar/b932ab599cea323ae457de5c8559af53?s=128&d=identicon&r=PG',
#     'display_name': 'Ibraheem',
#     'link': 'https://stackoverflow.com/users/1525751/ibraheem'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592729564,
#    'last_edit_date': 1592729564,
#    'creation_date': 1589669653,
#    'answer_id': 61844685,
#    'question_id': 7343890,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 41,
#     'user_id': 3630588,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/9ae7c88ce7afe1f575bf5944f7e32516?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Clark Thomborson',
#     'link': 'https://stackoverflow.com/users/3630588/clark-thomborson'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1592724996,
#    'last_edit_date': 1592724996,
#    'creation_date': 1588468272,
#    'answer_id': 61568429,
#    'question_id': 5404277,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 21,
#     'user_id': 11802944,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-wKWFUcmRYjo/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3rdZMYJAwvAfa74RmvJw2hiU4o8QbA/photo.jpg?sz=128',
#     'display_name': 'Samruddhi Chitnis',
#     'link': 'https://stackoverflow.com/users/11802944/samruddhi-chitnis'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592723866,
#    'last_edit_date': 1592723866,
#    'creation_date': 1589010951,
#    'answer_id': 61693506,
#    'question_id': 45276340,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 11,
#     'user_id': 4991417,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/c99558e53fb2cb057e92006386c181e3?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'GTP',
#     'link': 'https://stackoverflow.com/users/4991417/gtp'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592714947,
#    'last_edit_date': 1592714947,
#    'creation_date': 1590828669,
#    'answer_id': 62100078,
#    'question_id': 13652969,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 11,
#     'user_id': 11505622,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/05Ftk.jpg?s=128&g=1',
#     'display_name': 'dheeraj9499',
#     'link': 'https://stackoverflow.com/users/11505622/dheeraj9499'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592714432,
#    'last_edit_date': 1592714432,
#    'creation_date': 1589171779,
#    'answer_id': 61722361,
#    'question_id': 54345910,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1217,
#     'user_id': 4637583,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/532a2d09f5168f19818a1e8cf2ebaabd?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Alan Hoover',
#     'link': 'https://stackoverflow.com/users/4637583/alan-hoover'},
#    'is_accepted': True,
#    'score': 2,
#    'last_activity_date': 1592684098,
#    'last_edit_date': 1592684098,
#    'creation_date': 1590420065,
#    'answer_id': 62005537,
#    'question_id': 62005043,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 5340,
#     'user_id': 9606851,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/w9QmD.jpg?s=128&g=1',
#     'display_name': 'AbolfazlR',
#     'link': 'https://stackoverflow.com/users/9606851/abolfazlr'},
#    'is_accepted': False,
#    'score': 9,
#    'last_activity_date': 1592683809,
#    'last_edit_date': 1592683809,
#    'creation_date': 1590578680,
#    'answer_id': 62041941,
#    'question_id': 57216110,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 25608,
#     'user_id': 815724,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/9a514cd424088a3ba3012f5d77f2e334?s=128&d=identicon&r=PG',
#     'display_name': 'Peter O.',
#     'link': 'https://stackoverflow.com/users/815724/peter-o'},
#    'is_accepted': True,
#    'score': 2,
#    'last_activity_date': 1592679779,
#    'last_edit_date': 1592679779,
#    'creation_date': 1588348520,
#    'answer_id': 61545976,
#    'question_id': 61545598,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 4343,
#     'user_id': 2188922,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/690fef9d529a42ed8a9643c8883f4e8e?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Ersoy',
#     'link': 'https://stackoverflow.com/users/2188922/ersoy'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1592674224,
#    'last_edit_date': 1592674224,
#    'creation_date': 1588670841,
#    'answer_id': 61609876,
#    'question_id': 61609524,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 567,
#     'user_id': 1673752,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/h87Yt.jpg?s=128&g=1',
#     'display_name': 'P_P',
#     'link': 'https://stackoverflow.com/users/1673752/p-p'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592668622,
#    'last_edit_date': 1592668622,
#    'creation_date': 1590310665,
#    'answer_id': 61983714,
#    'question_id': 9673,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 15641,
#     'user_id': 6482561,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/9cd2b0768a40f668d90cf6f2b8b17caa?s=128&d=identicon&r=PG',
#     'display_name': 'Vladimir Botka',
#     'link': 'https://stackoverflow.com/users/6482561/vladimir-botka'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592666896,
#    'last_edit_date': 1592644375,
#    'creation_date': 1588866314,
#    'answer_id': 61662006,
#    'question_id': 61661683,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 178,
#     'user_id': 6043083,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/A2NK7.jpg?s=128&g=1',
#     'display_name': 'Rohit Nandi',
#     'link': 'https://stackoverflow.com/users/6043083/rohit-nandi'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1592666041,
#    'last_edit_date': 1592666041,
#    'creation_date': 1589705274,
#    'answer_id': 61849196,
#    'question_id': 42531056,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 182,
#     'user_id': 9995930,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/393dbf044587ab652ab45f06bea5d405?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Ravikant Singh',
#     'link': 'https://stackoverflow.com/users/9995930/ravikant-singh'},
#    'is_accepted': False,
#    'score': -1,
#    'last_activity_date': 1592665745,
#    'last_edit_date': 1592665745,
#    'creation_date': 1589644093,
#    'answer_id': 61839455,
#    'question_id': 54736096,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 13287026,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-Vd5kQ6wskE0/AAAAAAAAAAI/AAAAAAAAAAA/AAKWJJOQjY5aPCrF7rAdXnBrQrTSyST_fQ/photo.jpg?sz=128',
#     'display_name': 'AmanAgrawalTech',
#     'link': 'https://stackoverflow.com/users/13287026/amanagrawaltech'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592664261,
#    'last_edit_date': 1592664261,
#    'creation_date': 1590684300,
#    'answer_id': 62070082,
#    'question_id': 19669248,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 21,
#     'user_id': 12246922,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/05c5cb5fe73f46fd948ff444ef1ca48d?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Vasko',
#     'link': 'https://stackoverflow.com/users/12246922/vasko'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1592663185,
#    'last_edit_date': 1592663185,
#    'creation_date': 1589349259,
#    'answer_id': 61767363,
#    'question_id': 26264814,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 23538,
#     'user_id': 1119863,
#     'user_type': 'registered',
#     'accept_rate': 83,
#     'profile_image': 'https://i.stack.imgur.com/dhjKf.jpg?s=128&g=1',
#     'display_name': 'Marcos Casagrande',
#     'link': 'https://stackoverflow.com/users/1119863/marcos-casagrande'},
#    'is_accepted': True,
#    'score': 3,
#    'last_activity_date': 1592662027,
#    'last_edit_date': 1592662027,
#    'creation_date': 1590101365,
#    'answer_id': 61945064,
#    'question_id': 61945050,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 2332,
#     'user_id': 1025379,
#     'user_type': 'registered',
#     'accept_rate': 29,
#     'profile_image': 'https://i.stack.imgur.com/W87aD.png?s=128&g=1',
#     'display_name': 'Changhoon',
#     'link': 'https://stackoverflow.com/users/1025379/changhoon'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592661279,
#    'last_edit_date': 1592661279,
#    'creation_date': 1590712614,
#    'answer_id': 62076775,
#    'question_id': 59002502,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 344,
#     'user_id': 8449612,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/b47d4a395a39d555b1844ec9c0142f03?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'pszrux',
#     'link': 'https://stackoverflow.com/users/8449612/pszrux'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592657977,
#    'last_edit_date': 1592657977,
#    'creation_date': 1589252058,
#    'answer_id': 61742968,
#    'question_id': 61742539,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 31,
#     'user_id': 9681882,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/805b2f369269c30c7478b50dd175cadd?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Anubhav Gupta',
#     'link': 'https://stackoverflow.com/users/9681882/anubhav-gupta'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592657895,
#    'last_edit_date': 1592657895,
#    'creation_date': 1589182537,
#    'answer_id': 61724497,
#    'question_id': 43090718,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'user_type': 'does_not_exist', 'display_name': 'user11716837'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592656342,
#    'last_edit_date': 1592656342,
#    'creation_date': 1588404361,
#    'answer_id': 61555839,
#    'question_id': 39507506,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 9218,
#     'user_id': 447901,
#     'user_type': 'registered',
#     'accept_rate': 66,
#     'profile_image': 'https://www.gravatar.com/avatar/11ea5dd4ad290e75422e32e1e340772e?s=128&d=identicon&r=PG',
#     'display_name': 'lit',
#     'link': 'https://stackoverflow.com/users/447901/lit'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592655256,
#    'last_edit_date': 1592655256,
#    'creation_date': 1590588649,
#    'answer_id': 62045178,
#    'question_id': 62026148,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 516,
#     'user_id': 6120381,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/d7cb1fb2c79aae57df57eef8fe4c9d38?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Hietsh Kumar',
#     'link': 'https://stackoverflow.com/users/6120381/hietsh-kumar'},
#    'is_accepted': True,
#    'score': 0,
#    'last_activity_date': 1592654856,
#    'last_edit_date': 1592654856,
#    'creation_date': 1590392466,
#    'answer_id': 61997863,
#    'question_id': 61973047,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 30073,
#     'user_id': 129130,
#     'user_type': 'registered',
#     'accept_rate': 79,
#     'profile_image': 'https://i.stack.imgur.com/FJpdt.gif?s=128&g=1',
#     'display_name': 'Stein &#197;smul',
#     'link': 'https://stackoverflow.com/users/129130/stein-%c3%85smul'},
#    'is_accepted': True,
#    'score': 1,
#    'last_activity_date': 1592654388,
#    'last_edit_date': 1592654388,
#    'creation_date': 1590580006,
#    'answer_id': 62042369,
#    'question_id': 62035944,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 5753,
#     'user_id': 3231778,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://www.gravatar.com/avatar/05b3786d38ece9ae5b494ce48cc33a6b?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Evandro Pomatti',
#     'link': 'https://stackoverflow.com/users/3231778/evandro-pomatti'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592653293,
#    'last_edit_date': 1592653293,
#    'creation_date': 1589990530,
#    'answer_id': 61917606,
#    'question_id': 61917605,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1886,
#     'user_id': 1469663,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/d5d3e29cc385b2915d4bb8d60cb2e9fc?s=128&d=identicon&r=PG',
#     'display_name': 'Adi Dembak',
#     'link': 'https://stackoverflow.com/users/1469663/adi-dembak'},
#    'is_accepted': True,
#    'score': 2,
#    'last_activity_date': 1592649297,
#    'last_edit_date': 1592649297,
#    'creation_date': 1589282101,
#    'answer_id': 61750299,
#    'question_id': 61749835,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 341,
#     'user_id': 972368,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/95e30dee9d45c3a485425d2cfb5df9e9?s=128&d=identicon&r=PG',
#     'display_name': 'wllbll',
#     'link': 'https://stackoverflow.com/users/972368/wllbll'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592644026,
#    'last_edit_date': 1592644026,
#    'creation_date': 1590559263,
#    'answer_id': 62036418,
#    'question_id': 25699439,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1776,
#     'user_id': 8610127,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/cbbae91883f4056fa54d34cc4d73e67e?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'BeHappy',
#     'link': 'https://stackoverflow.com/users/8610127/behappy'},
#    'is_accepted': True,
#    'score': 2,
#    'last_activity_date': 1592642939,
#    'last_edit_date': 1592642939,
#    'creation_date': 1590725768,
#    'answer_id': 62078630,
#    'question_id': 62078458,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 76,
#     'user_id': 13266974,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/a618d5e21985e4cd307188d0cd5f45c5?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'sven',
#     'link': 'https://stackoverflow.com/users/13266974/sven'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592639894,
#    'last_edit_date': 1592639894,
#    'creation_date': 1590510874,
#    'answer_id': 62027029,
#    'question_id': 62026207,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 43,
#     'user_id': 5587903,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/0e8925b2d926e8972a57d43233d2d185?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'ktnr',
#     'link': 'https://stackoverflow.com/users/5587903/ktnr'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1592629567,
#    'last_edit_date': 1592629567,
#    'creation_date': 1590317370,
#    'answer_id': 61984830,
#    'question_id': 43170526,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 976,
#     'user_id': 3391490,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://i.stack.imgur.com/HIPFa.jpg?s=128&g=1',
#     'display_name': 'Thirumal',
#     'link': 'https://stackoverflow.com/users/3391490/thirumal'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592626287,
#    'last_edit_date': 1592626287,
#    'creation_date': 1590078307,
#    'answer_id': 61939142,
#    'question_id': 61566325,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1140,
#     'user_id': 9953396,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/CwX90.jpg?s=128&g=1',
#     'display_name': 'Mu-Tsun Tsai',
#     'link': 'https://stackoverflow.com/users/9953396/mu-tsun-tsai'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1592624671,
#    'last_edit_date': 1592624671,
#    'creation_date': 1589512692,
#    'answer_id': 61811139,
#    'question_id': 61368548,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 482,
#     'user_id': 13473361,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/84ba4c4c9cb61eef447a76125db58a20?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Gorka',
#     'link': 'https://stackoverflow.com/users/13473361/gorka'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592614373,
#    'last_edit_date': 1592614373,
#    'creation_date': 1590481800,
#    'answer_id': 62017731,
#    'question_id': 62015547,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1946,
#     'user_id': 8861638,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/JEo3P.png?s=128&g=1',
#     'display_name': 'Sultan H.',
#     'link': 'https://stackoverflow.com/users/8861638/sultan-h'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1592612805,
#    'last_edit_date': 1592612805,
#    'creation_date': 1589666202,
#    'answer_id': 61844126,
#    'question_id': 61843997,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 11,
#     'user_id': 10002535,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/d25da58d0240dfc55e739fb91ae06b5c?s=128&d=identicon&r=PG',
#     'display_name': 'sayhello',
#     'link': 'https://stackoverflow.com/users/10002535/sayhello'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1592601900,
#    'last_edit_date': 1592601900,
#    'creation_date': 1590768125,
#    'answer_id': 62090080,
#    'question_id': 62053705,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 10486,
#     'user_id': 5846045,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/oWcDn.jpg?s=128&g=1',
#     'display_name': 'Boghyon Hoffmann',
# ...
#     'display_name': 'Jim Jones',
#     'link': 'https://stackoverflow.com/users/2275388/jim-jones'},
#    'is_accepted': True,
#    'score': 2,
#    'last_activity_date': 1591861152,
#    'last_edit_date': 1591861152,
#    'creation_date': 1590582059,
#    'answer_id': 62043029,
#    'question_id': 62031459,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 382,
#     'user_id': 3344853,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/ca84ab1d9cd0afc5d15e645d3d92d26c?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'tim',
#     'link': 'https://stackoverflow.com/users/3344853/tim'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1591857988,
#    'last_edit_date': 1591857988,
#    'creation_date': 1590677622,
#    'answer_id': 62067752,
#    'question_id': 61630181,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 316,
#     'user_id': 12539296,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/e43f9874a48bec9134f69d66b7e8d6bc?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'whathm',
#     'link': 'https://stackoverflow.com/users/12539296/whathm'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1591857730,
#    'last_edit_date': 1591857730,
#    'creation_date': 1590012014,
#    'answer_id': 61923684,
#    'question_id': 61923205,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 84778,
#     'user_id': 1945651,
#     'user_type': 'registered',
#     'accept_rate': 86,
#     'profile_image': 'https://i.stack.imgur.com/9J4D8.png?s=128&g=1',
#     'display_name': 'JLRishe',
#     'link': 'https://stackoverflow.com/users/1945651/jlrishe'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1591855051,
#    'last_edit_date': 1591855051,
#    'creation_date': 1590489019,
#    'answer_id': 62020065,
#    'question_id': 18178597,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 3752,
#     'user_id': 4440327,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/1391012609/picture?type=large',
#     'display_name': 'Sebasti&#225;n Lara',
#     'link': 'https://stackoverflow.com/users/4440327/sebasti%c3%a1n-lara'},
#    'is_accepted': False,
#    'score': -1,
#    'last_activity_date': 1591844777,
#    'last_edit_date': 1591844777,
#    'creation_date': 1589683602,
#    'answer_id': 61846347,
#    'question_id': 10666349,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 12942065,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AAuE7mDTDywgKBnsx_uQ2hiPmLB_tgGa4kBk_ILd43H_GA=k-s128',
#     'display_name': 'Rajendro Sau',
#     'link': 'https://stackoverflow.com/users/12942065/rajendro-sau'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1591839106,
#    'last_edit_date': 1591839106,
#    'creation_date': 1589956030,
#    'answer_id': 61906481,
#    'question_id': 46755482,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 13497396,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/1fe81d90cb9c72eb7e1d70d4088defce?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Kirin_CN',
#     'link': 'https://stackoverflow.com/users/13497396/kirin-cn'},
#    'is_accepted': False,
#    'score': -1,
#    'last_activity_date': 1591838452,
#    'last_edit_date': 1591838452,
#    'creation_date': 1588929037,
#    'answer_id': 61675743,
#    'question_id': 48183182,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 171,
#     'user_id': 12595823,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AAuE7mC775FphjYi1A6CiWbbqTzX1FtreSBBcGMrvlhd=k-s128',
#     'display_name': 'Muhammad Adam',
#     'link': 'https://stackoverflow.com/users/12595823/muhammad-adam'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1591836283,
#    'last_edit_date': 1591836283,
#    'creation_date': 1589843199,
#    'answer_id': 61880492,
#    'question_id': 54496941,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 33,
#     'user_id': 13351917,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/4d89050eac8f26685d38a7daca277709?s=128&d=identicon&r=PG',
#     'display_name': 'Dave',
#     'link': 'https://stackoverflow.com/users/13351917/dave'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1591833871,
#    'last_edit_date': 1591833871,
#    'creation_date': 1590648371,
#    'answer_id': 62058604,
#    'question_id': 61555758,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 849,
#     'user_id': 2480947,
#     'user_type': 'registered',
#     'accept_rate': 60,
#     'profile_image': 'https://i.stack.imgur.com/0fI4r.png?s=128&g=1',
#     'display_name': 'Nick',
#     'link': 'https://stackoverflow.com/users/2480947/nick'},
#    'is_accepted': True,
#    'score': 1,
#    'last_activity_date': 1591831222,
#    'last_edit_date': 1591831222,
#    'creation_date': 1589320527,
#    'answer_id': 61762703,
#    'question_id': 61740085,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 594,
#     'user_id': 3115229,
#     'user_type': 'registered',
#     'accept_rate': 80,
#     'profile_image': 'https://www.gravatar.com/avatar/64656d2413aa5bec613c31c4cbfad80d?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Suren Aznauryan',
#     'link': 'https://stackoverflow.com/users/3115229/suren-aznauryan'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1591830800,
#    'last_edit_date': 1591830800,
#    'creation_date': 1590440110,
#    'answer_id': 62010641,
#    'question_id': 47092029,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 2608,
#     'user_id': 2931925,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/lTTXF.png?s=128&g=1',
#     'display_name': 'Charles',
#     'link': 'https://stackoverflow.com/users/2931925/charles'},
#    'is_accepted': True,
#    'score': 1,
#    'last_activity_date': 1591830344,
#    'last_edit_date': 1591830344,
#    'creation_date': 1588362164,
#    'answer_id': 61549613,
#    'question_id': 61541024,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 2608,
#     'user_id': 2931925,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/lTTXF.png?s=128&g=1',
#     'display_name': 'Charles',
#     'link': 'https://stackoverflow.com/users/2931925/charles'},
#    'is_accepted': True,
#    'score': 2,
#    'last_activity_date': 1591830285,
#    'last_edit_date': 1591830285,
#    'creation_date': 1588786843,
#    'answer_id': 61641656,
#    'question_id': 61625857,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 2608,
#     'user_id': 2931925,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/lTTXF.png?s=128&g=1',
#     'display_name': 'Charles',
#     'link': 'https://stackoverflow.com/users/2931925/charles'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1591830227,
#    'last_edit_date': 1591830227,
#    'creation_date': 1589912923,
#    'answer_id': 61898188,
#    'question_id': 61892629,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 2608,
#     'user_id': 2931925,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/lTTXF.png?s=128&g=1',
#     'display_name': 'Charles',
#     'link': 'https://stackoverflow.com/users/2931925/charles'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1591830198,
#    'last_edit_date': 1591830198,
#    'creation_date': 1589890738,
#    'answer_id': 61890902,
#    'question_id': 61889395,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 2608,
#     'user_id': 2931925,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/lTTXF.png?s=128&g=1',
#     'display_name': 'Charles',
#     'link': 'https://stackoverflow.com/users/2931925/charles'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1591830186,
#    'last_edit_date': 1591830186,
#    'creation_date': 1589662752,
#    'answer_id': 61843477,
#    'question_id': 61778620,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 2931,
#     'user_id': 8038186,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/72ac0cc4d0f1414caf2172751b2ded50?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'KorelK',
#     'link': 'https://stackoverflow.com/users/8038186/korelk'},
#    'is_accepted': True,
#    'score': 0,
#    'last_activity_date': 1591829458,
#    'last_edit_date': 1591829458,
#    'creation_date': 1590852120,
#    'answer_id': 62104568,
#    'question_id': 62091515,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 8591,
#     'user_id': 595605,
#     'user_type': 'registered',
#     'accept_rate': 72,
#     'profile_image': 'https://www.gravatar.com/avatar/3b71ec2390b9ed0035f73222eb1bfa72?s=128&d=identicon&r=PG',
#     'display_name': 'Drew',
#     'link': 'https://stackoverflow.com/users/595605/drew'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1591828356,
#    'last_edit_date': 1591828356,
#    'creation_date': 1588379790,
#    'answer_id': 61552951,
#    'question_id': 998571,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 14663,
#     'user_id': 3437787,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://i.stack.imgur.com/W8tmU.jpg?s=128&g=1',
#     'display_name': 'vestland',
#     'link': 'https://stackoverflow.com/users/3437787/vestland'},
#    'is_accepted': True,
#    'score': 1,
#    'last_activity_date': 1591827002,
#    'last_edit_date': 1591827002,
#    'creation_date': 1590405842,
#    'answer_id': 62001422,
#    'question_id': 61986676,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 21,
#     'user_id': 12404261,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/8bc526c62814de1e3b8a559cbd718548?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'ViMan',
#     'link': 'https://stackoverflow.com/users/12404261/viman'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1591824731,
#    'last_edit_date': 1591824731,
#    'creation_date': 1589921052,
#    'answer_id': 61900440,
#    'question_id': 21675758,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 414,
#     'user_id': 1026576,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/bbe1e8eedbba4dedfb6a9c410bed8558?s=128&d=identicon&r=PG',
#     'display_name': 'Ryan Vettese',
#     'link': 'https://stackoverflow.com/users/1026576/ryan-vettese'},
#    'is_accepted': True,
#    'score': 1,
#    'last_activity_date': 1591823986,
#    'last_edit_date': 1591823986,
#    'creation_date': 1590773604,
#    'answer_id': 62091603,
#    'question_id': 57677035,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 562,
#     'user_id': 9592801,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/M59ib.jpg?s=128&g=1',
#     'display_name': 'Shakeel',
#     'link': 'https://stackoverflow.com/users/9592801/shakeel'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1591818359,
#    'last_edit_date': 1591818359,
#    'creation_date': 1588779073,
#    'answer_id': 61639130,
#    'question_id': 30855169,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 7072,
#     'user_id': 9164141,
#     'user_type': 'registered',
#     'accept_rate': 93,
#     'profile_image': 'https://i.stack.imgur.com/uiNcT.jpg?s=128&g=1',
#     'display_name': 'Gast&#243;n Saill&#233;n',
#     'link': 'https://stackoverflow.com/users/9164141/gast%c3%b3n-saill%c3%a9n'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1591818237,
#    'last_edit_date': 1591818237,
#    'creation_date': 1589289087,
#    'answer_id': 61752606,
#    'question_id': 48914311,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 3390,
#     'user_id': 1519318,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/aQRZQ.jpg?s=128&g=1',
#     'display_name': 'Tom Tom',
#     'link': 'https://stackoverflow.com/users/1519318/tom-tom'},
#    'is_accepted': True,
#    'score': 2,
#    'last_activity_date': 1591817940,
#    'last_edit_date': 1591817940,
#    'creation_date': 1590237353,
#    'answer_id': 61972130,
#    'question_id': 61966829,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1606,
#     'user_id': 1108697,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://www.gravatar.com/avatar/d782873c25fc92ccadf8e81cd9771bea?s=128&d=identicon&r=PG',
#     'display_name': 'andy.holmes',
#     'link': 'https://stackoverflow.com/users/1108697/andy-holmes'},
#    'is_accepted': True,
#    'score': 1,
#    'last_activity_date': 1591817078,
#    'last_edit_date': 1591817078,
#    'creation_date': 1590000023,
#    'answer_id': 61920511,
#    'question_id': 61901651,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 66,
#     'user_id': 11086758,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/ecb81ac5e3465347fba25e90d40b7390?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Henry',
#     'link': 'https://stackoverflow.com/users/11086758/henry'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1591816045,
#    'last_edit_date': 1591816045,
#    'creation_date': 1590752006,
#    'answer_id': 62085010,
#    'question_id': 1485841,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 623,
#     'user_id': 8761466,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/VhFs6.jpg?s=128&g=1',
#     'display_name': 'bsaverino',
#     'link': 'https://stackoverflow.com/users/8761466/bsaverino'},
#    'is_accepted': True,
#    'score': 0,
#    'last_activity_date': 1591814448,
#    'last_edit_date': 1591814448,
#    'creation_date': 1590793614,
#    'answer_id': 62095826,
#    'question_id': 62093845,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1343,
#     'user_id': 5655977,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/8b78d5c910e17fc9b944defe4b2942f7?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Sourcerer',
#     'link': 'https://stackoverflow.com/users/5655977/sourcerer'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1591813830,
#    'last_edit_date': 1591813830,
#    'creation_date': 1590048032,
#    'answer_id': 61929896,
#    'question_id': 6931342,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 158,
#     'user_id': 9654083,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/a07542057c32fa0ec484a700420bd141?s=128&d=identicon&r=PG',
#     'display_name': 'TheTechRobo36414519',
#     'link': 'https://stackoverflow.com/users/9654083/thetechrobo36414519'},
#    'is_accepted': True,
#    'score': 1,
#    'last_activity_date': 1591813581,
#    'last_edit_date': 1591813581,
#    'creation_date': 1589741502,
#    'answer_id': 61857070,
#    'question_id': 24768630,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 11,
#     'user_id': 8931363,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/373ac527173b205bfceb56d62627b08c?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Neal',
#     'link': 'https://stackoverflow.com/users/8931363/neal'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1591813326,
#    'last_edit_date': 1591813326,
#    'creation_date': 1590654933,
#    'answer_id': 62060345,
#    'question_id': 56798926,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 714,
#     'user_id': 13223056,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/aWYsh.jpg?s=128&g=1',
#     'display_name': 'KL_KISNE_DEKHA_HAI',
#     'link': 'https://stackoverflow.com/users/13223056/kl-kisne-dekha-hai'},
#    'is_accepted': True,
#    'score': 6,
#    'last_activity_date': 1591809497,
#    'last_edit_date': 1591809497,
#    'creation_date': 1589218752,
#    'answer_id': 61735790,
#    'question_id': 61735649,
#    'content_license': 'CC BY-SA 4.0'}]}

# %%
pd.DataFrame(questions)
# Out:
#      backoff  has_more  page  quota_max  quota_remaining  total  \
# 0          0      True     5        300              300      0
# 1          0      True     5        300              300      0
# 2          0      True     5        300              300      0
# 3          0      True     5        300              300      0
# 4          0      True     5        300              300      0
# ..       ...       ...   ...        ...              ...    ...
# 495        0      True     5        300              300      0
# 496        0      True     5        300              300      0
# 497        0      True     5        300              300      0
# 498        0      True     5        300              300      0
# 499        0      True     5        300              300      0
#
#                                                  items
# 0    {'tags': ['html', 'line-breaks', 'specificatio...
# 1    {'tags': ['python', 'python-3.x', 'macos', 'py...
# 2    {'tags': ['angular', 'nginx', 'cors'], 'owner'...
# 3    {'tags': ['python', 'python-3.x', 'django-mode...
# 4    {'tags': ['android', 'service', 'background', ...
# ..                                                 ...
# 495  {'tags': ['c#', 'asp.net', 'asp.net-core', 'ra...
# 496  {'tags': ['django', 'graphql', 'graphene-djang...
# 497  {'tags': ['python', 'pandas', 'function', 'dat...
# 498  {'tags': ['python', 'python-3.x', 'pandas', 'n...
# 499  {'tags': ['python', 'pandas', 'dataframe', 'cs...
#
# [500 rows x 7 columns]

# %%
pd.DataFrame(questions['items'])
# Out:
#                                                   tags  \
# 0                  [html, line-breaks, specifications]
# 1                  [python, python-3.x, macos, pygame]
# 2                               [angular, nginx, cors]
# 3      [python, python-3.x, django-models, django-3.0]
# 4    [android, service, background, huawei-mobile-s...
# ..                                                 ...
# 495                 [c#, asp.net, asp.net-core, razor]
# 496                 [django, graphql, graphene-django]
# 497      [python, pandas, function, dataframe, rename]
# 498     [python, python-3.x, pandas, numpy, dataframe]
# 499                   [python, pandas, dataframe, csv]
#
#                                                  owner  is_answered  \
# 0    {'reputation': 14535, 'user_id': 1993501, 'use...        False
# 1    {'reputation': 313, 'user_id': 13314450, 'user...        False
# 2    {'reputation': 11, 'user_id': 1615021, 'user_t...        False
# 3    {'reputation': 1038, 'user_id': 8382028, 'user...         True
# 4    {'reputation': 11, 'user_id': 5035838, 'user_t...        False
# ..                                                 ...          ...
# 495  {'reputation': 1633, 'user_id': 3960200, 'user...        False
# 496  {'reputation': 21, 'user_id': 8263882, 'user_t...         True
# 497  {'reputation': 97, 'user_id': 12077980, 'user_...         True
# 498  {'reputation': 17, 'user_id': 12308426, 'user_...         True
# 499  {'reputation': 43, 'user_id': 9692220, 'user_t...         True
#
#      view_count  bounty_amount  bounty_closes_date  answer_count  score  \
# 0            60          500.0        1.593432e+09             3      0
# 1           125           50.0        1.592872e+09             3      4
# 2            85            NaN                 NaN             1     -1
# 3            50            NaN                 NaN             1      1
# 4            51            NaN                 NaN             1      0
# ..          ...            ...                 ...           ...    ...
# 495          18            NaN                 NaN             1      0
# 496          32            NaN                 NaN             3     -1
# 497          55            NaN                 NaN             3      1
# 498          31            NaN                 NaN             2      1
# 499          39            NaN                 NaN             2      4
#
#      last_activity_date  creation_date  last_edit_date  question_id  \
# 0            1592858611     1589960236    1.589961e+09     61907540
# 1            1592856401     1590013538    1.592400e+09     61923965
# 2            1592855441     1589577604    1.592855e+09     61828546
# 3            1592854263     1589985921    1.590668e+09     61916022
# 4            1592854146     1588900325    1.592854e+09     61670377
# ..                  ...            ...             ...          ...
# 495          1592562888     1589826675    1.589828e+09     61876518
# 496          1592562397     1589910607             NaN     61897542
# 497          1592562002     1589432841    1.592562e+09     61789700
# 498          1592561894     1589878489    1.592562e+09     61887073
# 499          1592561815     1589976190    1.592562e+09     61912642
#
#     content_license                                               link  \
# 0      CC BY-SA 4.0  https://stackoverflow.com/questions/61907540/w...
# 1      CC BY-SA 4.0  https://stackoverflow.com/questions/61923965/p...
# 2      CC BY-SA 4.0  https://stackoverflow.com/questions/61828546/n...
# 3      CC BY-SA 4.0  https://stackoverflow.com/questions/61916022/d...
# 4      CC BY-SA 4.0  https://stackoverflow.com/questions/61670377/b...
# ..              ...                                                ...
# 495    CC BY-SA 4.0  https://stackoverflow.com/questions/61876518/r...
# 496    CC BY-SA 4.0  https://stackoverflow.com/questions/61897542/g...
# 497    CC BY-SA 4.0  https://stackoverflow.com/questions/61789700/c...
# 498    CC BY-SA 4.0  https://stackoverflow.com/questions/61887073/h...
# 499    CC BY-SA 4.0  https://stackoverflow.com/questions/61912642/h...
#
#                                                  title  accepted_answer_id  \
# 0    When are &lt;br&gt; elements ignored when with...                 NaN
# 1    PyGame slower on macOS than on Ubuntu or Raspbian                 NaN
# 2                          Nginx Cors Angular9 RestApi                 NaN
# 3    Django 3 Object Evaluation error due to from_d...          62517674.0
# 4    Background service closes when the screen is b...                 NaN
# ..                                                 ...                 ...
# 495  Render Raw HTML Request from Blazer Server (Te...                 NaN
# 496                      Graphene Django getting items                 NaN
# 497  Creating function to rename columns in pandas ...          61789782.0
# 498  How to compare the values in 2 columns of a da...          61887214.0
# 499  How to keep x highest person correlation value...          61912949.0
#
#      closed_date closed_reason  protected_date
# 0            NaN           NaN             NaN
# 1            NaN           NaN             NaN
# 2            NaN           NaN             NaN
# 3            NaN           NaN             NaN
# 4            NaN           NaN             NaN
# ..           ...           ...             ...
# 495          NaN           NaN             NaN
# 496          NaN           NaN             NaN
# 497          NaN           NaN             NaN
# 498          NaN           NaN             NaN
# 499          NaN           NaN             NaN
#
# [500 rows x 19 columns]

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here
SITE = StackAPI('stackoverflow')
answers = SITE.fetch('answers', ids=[6784, 6473])
answers
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 28855,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=128&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778,
#    'content_license': 'CC BY-SA 2.5'}]}
